# %% [markdown]
# <a href="https://colab.research.google.com/github/luizfilipisousamoura/QuantumComputing/blob/main/QuantumComputingWithQiskit/10_pauliXGateOnState1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install qiskit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 6.7 MB 6.6 MB/s
# ...
#      |████████████████████████████████| 19.2 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 240 kB 72.5 MB/s
# ...
#      |████████████████████████████████| 112 kB 61.4 MB/s
# ...
#      |████████████████████████████████| 55 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 37.5 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 49 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 49 kB 7.5 MB/s
# ...
#      |████████████████████████████████| 943 kB 81.8 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 53.6 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 50.0 MB/s
# ...
#      |████████████████████████████████| 112 kB 66.4 MB/s
# ...
#   Created wheel for qiskit: filename=qiskit-0.38.0-py3-none-any.whl size=12147 sha256=616e0e9510a1b084f3552e0a41e463af16975988e93e04500710d8f57e40aa86
# ...

# %%
# !pip3 install pylatexenc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 162 kB 8.2 MB/s
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136835 sha256=d9eb7a94892a03e6c93ff6641004f7ab2bc53b23be3152023e2e49bd167f2c0b
#   Stored in directory: /root/.cache/pip/wheels/f1/8a/f5/33ee79d4473eb201b519fa40f989b842e373237395a3421f52
# Successfully built pylatexenc
# ...

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, quantum_info, visualization
from qiskit.quantum_info import Statevector, DensityMatrix, state_fidelity
from qiskit.visualization import plot_state_qsphere, plot_state_city, plot_state_hinton, plot_state_paulivec, plot_bloch_multivector

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
qc = QuantumCircuit(q, c)

# %%
qc.x(q[0]) #Apply X gate in order to get ket(1) state, since the registers start in ket(0)

# %%
qc.draw('mpl')

# %%
psi1 = Statevector(qc)
psi1.draw('latex')
# Out:
# $$ |1\rangle$$

# %%
rho1 = DensityMatrix(qc)
rho1.draw('latex', prefix='\\rho_1 = ')
# Out:
# $$
# \rho_1 =
# \begin{bmatrix}
# 0 & 0  \\
#  0 & 1  \\
#  \end{bmatrix}
# $$

# %%
qc.x(q[0])

# %%
qc.draw('mpl')

# %%
psi2 = Statevector(qc)
psi2.draw('latex')
# Out:
# $$ |0\rangle$$

# %%
rho2 = DensityMatrix(qc)
rho2.draw('latex', prefix='\\rho_2 = ')
# Out:
# $$
# \rho_2 =
# \begin{bmatrix}
# 1 & 0  \\
#  0 & 0  \\
#  \end{bmatrix}
# $$

# %%
plot_state_qsphere(qc)

# %%
plot_state_city(qc)

# %%
plot_state_hinton(qc)

# %%
plot_bloch_multivector(qc)

# %%
purity = rho2.purity()
print(purity)
# Out:
# (1+0j)

# %%
fidelity = state_fidelity(psi1, psi2)
print('Fidelity = ', fidelity)
# Out:
# Fidelity =  0.0

# %%
fidelity = state_fidelity(rho1, rho2)
print('Fidelity = ', fidelity)
# Out:
# Fidelity =  0.0

# %%
qc.measure(q[0], c[0])

# %%
qc.draw('mpl')

# %%
from qiskit import transpile
from qiskit.providers.aer import QasmSimulator
backend = QasmSimulator()
qc_compiled = transpile(qc,backend)
job = backend.run(qc_compiled,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
# Out:
# {'0': 1024}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(counts)
